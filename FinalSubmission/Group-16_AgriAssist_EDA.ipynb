# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Uploaded dataset in the Github and given the dataset path
data_file = "https://raw.githubusercontent.com/Dhanush-Garrepalli/AgriAssist/main/dataset_soil_nutrients.csv"
soil_nutrients_df = pd.read_csv(data_file)

# %%
soil_nutrients_df.head(20)
# Out:
#       N    P    K    pH    EC    OC     S    Zn    Fe    Cu    Mn     B  \
# 0   138  8.6  560  7.46  0.62  0.70   5.9  0.24  0.31  0.77  8.71  0.11
# 1   213  7.5  338  7.62  0.75  1.06  25.4  0.30  0.86  1.54  2.89  2.29
# 2   163  9.6  718  7.59  0.51  1.11  14.3  0.30  0.86  1.57  2.70  2.03
# 3   157  6.8  475  7.64  0.58  0.94  26.0  0.34  0.54  1.53  2.65  1.82
# 4   270  9.9  444  7.63  0.40  0.86  11.8  0.25  0.76  1.69  2.43  2.26
# 5   220  8.6  444  7.43  0.65  0.72  11.7  0.37  0.66  0.90  2.19  1.82
# 6   220  7.2  222  7.62  0.43  0.81   7.4  0.34  0.69  1.05  2.00  1.88
# 7   207  7.0  401  7.63  0.59  0.69   7.6  0.32  0.68  0.62  2.43  1.68
# 8   289  8.6  560  7.58  0.44  0.67   7.3  0.63  0.66  0.94  2.43  1.79
# 9   138  8.1  739  7.55  0.33  0.78   9.0  0.69  0.41  1.15  2.75  2.00
# 10  151  8.1  549  7.59  0.45  0.97   9.6  0.71  0.38  1.33  2.79  2.41
# 11  144  7.2  306  7.53  0.73  0.89   9.2  0.63  0.47  1.03  2.79  2.38
# ...

# %%
#Checking for null values
soil_nutrients_df.isna().any()
# Out:
# N         False
# P         False
# K         False
# pH        False
# EC        False
# OC        False
# S         False
# Zn        False
# Fe        False
# Cu        False
# Mn        False
# B         False
# Output    False
# dtype: bool

# %%
#calculating the dimensions of the dataset
soil_nutrients_df.shape
# Out:
# (880, 13)

# %%
#Checking the datatype for each and every feature in the data
soil_nutrients_df.dtypes
# Out:
# N           int64
# P         float64
# K           int64
# pH        float64
# EC        float64
# OC        float64
# S         float64
# Zn        float64
# Fe        float64
# Cu        float64
# Mn        float64
# B         float64
# Output      int64
# dtype: object

# %%
#Statistics and description of the dataset for each and every feature
soil_nutrients_df.describe().T
# Out:
#         count        mean         std    min      25%      50%       75%  \
# N       880.0  246.737500   77.388860   6.00  201.000  257.000  307.0000
# P       880.0   14.562159   21.967755   2.90    6.800    8.100   10.5500
# K       880.0  499.978409  124.222838  11.00  412.000  475.000  581.0000
# pH      880.0    7.510500    0.464912   0.90    7.350    7.500    7.6300
# EC      880.0    0.543659    0.141597   0.10    0.430    0.545    0.6400
# OC      880.0    0.617989    0.842986   0.10    0.380    0.590    0.7800
# S       880.0    7.545080    4.424184   0.64    4.700    6.640    8.7500
# Zn      880.0    0.469273    1.894234   0.07    0.280    0.360    0.4700
# Fe      880.0    4.140523    3.110011   0.21    2.050    3.565    6.3200
# Cu      880.0    0.952443    0.465900   0.09    0.630    0.930    1.2500
# Mn      880.0    8.666500    4.298828   0.11    6.225    8.345   11.4725
# B       880.0    0.590159    0.570800   0.06    0.270    0.405    0.6100
# ...

# %% [markdown]
# ### **Feature distribution within the dataset**

# %%
sns.distplot(soil_nutrients_df['P'])
plt.show()

# %%
sns.distplot(soil_nutrients_df['K'])
plt.show()

# %%
sns.distplot(soil_nutrients_df['pH'])
plt.show()

# %%
soil_nutrients_df.head()
# Out:
#      N    P    K    pH    EC    OC     S    Zn    Fe    Cu    Mn     B  Output
# 0  138  8.6  560  7.46  0.62  0.70   5.9  0.24  0.31  0.77  8.71  0.11       0
# 1  213  7.5  338  7.62  0.75  1.06  25.4  0.30  0.86  1.54  2.89  2.29       0
# 2  163  9.6  718  7.59  0.51  1.11  14.3  0.30  0.86  1.57  2.70  2.03       0
# 3  157  6.8  475  7.64  0.58  0.94  26.0  0.34  0.54  1.53  2.65  1.82       0
# 4  270  9.9  444  7.63  0.40  0.86  11.8  0.25  0.76  1.69  2.43  2.26       1

# %%
df_corr = soil_nutrients_df[['K', 'S', 'Zn', 'Fe', 'Cu', 'Mn', 'B']].corr()
df_corr
# Out:
#            K         S        Zn        Fe        Cu        Mn         B
# K   1.000000  0.026489 -0.002511 -0.053442 -0.005597  0.021157  0.108025
# S   0.026489  1.000000 -0.013870 -0.208752  0.158130 -0.226249  0.478017
# Zn -0.002511 -0.013870  1.000000  0.548485 -0.051229 -0.065154  0.056252
# Fe -0.053442 -0.208752  0.548485  1.000000  0.138121  0.275564 -0.332181
# Cu -0.005597  0.158130 -0.051229  0.138121  1.000000  0.079934  0.101115
# Mn  0.021157 -0.226249 -0.065154  0.275564  0.079934  1.000000 -0.413963
# B   0.108025  0.478017  0.056252 -0.332181  0.101115 -0.413963  1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(soil_nutrients_df, vars=['N','P','K','pH','S','Zn','Fe'])
plt.show()
